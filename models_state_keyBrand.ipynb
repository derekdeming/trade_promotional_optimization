# %%
# Data processing
import pandas as pd
import numpy as np
from pyspark.sql.functions import log, col, exp, when, col, avg, count
from pyspark.sql.functions import weekofyear, month, quarter, year
from pyspark.sql.window import Window 
import pyspark.sql.functions as func
# Modeling
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
# MLflow
import mlflow
import mlflow.spark
from mlflow.tracking import MlflowClient

# %%
# %run ./utils/Forecasting_Utils

# %%
kbm = KeyBrandModel()
testss = {'weekofyear': [3], 'month': [1], 'quarter':[1], 'year':[2021]}
kbm.predict(testss, 'WY', 'DR PEPPER')
# Out:
# Out[48]: [8.03576760554597]

# %%
kpm = KeyPackageModel()
testss = {'weekofyear': [3], 'month': [1], 'quarter':[1], 'year':[2021]}
kpm.predict(testss, 'WY', '2L SINGLE BOTTLE')
# Out:
# Out[49]: [2.5338889419199404]

# %%
# Enable autolog()
mlflow.sklearn.autolog()
# With autolog() enabled, all model parameters, a model score, and the fitted model are automatically logged. 


dep_var = 'avg_standard_physical_volume'
indep_vars = ['weekofyear', 'month', 'quarter', 'year']
cnt = 0        
for state in kbm.states_list:
    for brand in kbm.keys_list:
        cnt +=1
        kbm.get_model_name(state, brand)
        
        df = kbm.get_filtered_series(state, brand)
        df = kbm.append_time_features(df)
        sdf = df.select(indep_vars + [dep_var])
        
        print(f"#### working on model {model_name} ####")
        print(f"### model {cnt} out of {len(kbm.states_list)*len(kbm.keys_list)} models")
        
        # Train test split
        trainDF, testDF = sdf.randomSplit([.8, .2], seed=42)
        # Print the number of records
        print(f'There are {trainDF.cache().count()} records in the training dataset.')
        print(f'There are {testDF.cache().count()} records in the testing dataset.')

        if trainDF.count()==0 or testDF.count()==0:
            print('^^^ This Dataset has zero data points and will be excluded')
            continue
            
        with mlflow.start_run(run_name=model_name) as run:
            # Define pipeline
            elastic_net_param = 0.5
            vecAssembler = VectorAssembler(inputCols=indep_vars, outputCol="features")
            lr = LinearRegression(featuresCol="features", labelCol=dep_var, predictionCol="prediction",elasticNetParam=elastic_net_param)
            pipeline = Pipeline(stages=[vecAssembler, lr])
            pipelineModel = pipeline.fit(trainDF)
            # Log parameters
            mlflow.log_param("target_variable", dep_var)
            mlflow.log_param("elasticNetParam", elastic_net_param)
            # Log the model for this run
            mlflow.spark.log_model(pipelineModel, "SparkML-linear-regression")
            # Make predictions
            predDF = pipelineModel.transform(testDF)    

            # Evaluate predictions
            regressionEvaluator = RegressionEvaluator(predictionCol="prediction", labelCol=dep_var)
            rmse = regressionEvaluator.setMetricName("rmse").evaluate(predDF)
            r2 = regressionEvaluator.setMetricName("r2").evaluate(predDF)
            mse = regressionEvaluator.setMetricName("mse").evaluate(predDF)
            mae = regressionEvaluator.setMetricName("mae").evaluate(predDF)

            # Log metrics
            mlflow.log_metric("rmse", rmse)
            mlflow.log_metric("r2", r2)    
            mlflow.log_metric("mse", mse)    
            mlflow.log_metric("mae", mae)    
            print(f'r2 is {r2}')
            print(f'rmse is {rmse}')
            print(f'mse is {mse}')
            print(f'mae is {mae}')
            print(f'*************************************')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
get_model_name = lambda state, keyVal: (state + '_' + keyVal).replace(" ", "_").replace(".", "_")

model_name('AZ', 'COKE')
# Out:
# Out[14]: 'AZ_COKE'

# %%
model_list = []
for state in kbm.states_list:
    for brand in kbm.keys_list:
        model_name = get_model_name(state,brand) 
        model_list.append(model_name)
        
print(len(model_list))
model_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4394589272978365>:2
#       1 model_list = []
# ----> 2 for state in kbm.states_list:
#       3     for brand in kbm.keys_list:
#       4         model_name = get_model_name(state,brand)
#
# NameError: name 'kbm' is not defined

# %%
def make_prediction(model_params_dict: dict, state: str, keyCol: str):
    run_name_col = 'run_name'
    experiments = mlflow.MlflowClient().search_experiments()
    experiment_ids = [dict(x).get('experiment_id') for x in experiments if dict(x).get('name').find('keyBrand') >=0]
    
    runs_df = mlflow.search_runs(experiment_ids, order_by=["tags.mlflow.runName ASC"]).\
            rename({'tags.mlflow.runName':run_name_col}, axis=1)[['run_id',run_name_col]]
    
    
    model_name = kbm.get_model_name(state, keyCol)
    run_id = runs_df[runs_df[run_name_col] == model_name]['run_id'].values[0]
    
    model_uri = f'runs:/{run_id}/SparkML-linear-regression'
    
    # Load model as a PyFuncModel.
    model = mlflow.pyfunc.load_model(model_uri)
    
    # Predict on a Pandas DataFrame.
    results = model.predict(pd.DataFrame(model_params_dict))
    
    return results
    

make_prediction(testss, 'WY', 'COKE')
# Out:
# Out[94]: [16.60153277201789]

# %%
T
# Out:
# Out[93]: [16.60153277201789]

# %%
make_prediction(testss, 'AZ', 'COKE')
# Out:
# Out[95]: [16.60153277201789]

# %%
experiments = mlflow.MlflowClient().search_experiments()
#mlf_client
experiment_ids = [dict(x).get('experiment_id') for x in experiments if dict(x).get('name').find('keyBrand') >=0]
runs_df = mlflow.search_runs(experiment_ids, order_by=["tags.mlflow.runName ASC"]).\
            rename({'tags.mlflow.runName':'run_name'}, axis=1)[['run_id','run_name']]
display(runs_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>run_id</th><th>run_name</th></tr></thead><tbody><tr><td>4435f593e60c4dc8afec8c6996ec97fe</td><td>AZ_CHERRY_COKE</td></tr><tr><td>2e31412305ca41f280a981bc4fb9b178</td><td>AZ_CINNAMON_COKE</td></tr><tr><td>5839cc0e725a49e08210e7e0f59b8110</td><td>AZ_COCA-COLA_DREAMWORLD</td></tr><tr><td>23bcb4eed9c24bca8566e04afbe63c4a</td><td>AZ_COKE</td></tr><tr><td>7cebcd6f493c4273be56c78ec37a264b</td><td>AZ_COKE_CF</td></tr><tr><td>d37fa577d28a4309849ca2e269755534</td><td>AZ_COKE_CHERRY_VANILLA</td></tr><tr><td>fba7fa3ceb634959bc39cbb64348bb50</td><td>AZ_COKE_STARLIGHT</td></tr><tr><td>6856e99931ee4fa19c89b4263354bd7a</td><td>AZ_COKE_W/LIME</td></tr><tr><td>4cf082c7ffc74ce69637864a4db63a1a</td><td>AZ_DIET_DR_PEPPER</td></tr><tr><td>f1a692a181e24ef7b776e2b579c74ee5</td><td>AZ_DIET_DR_PEPPER_10</td></tr><tr><td>1262f8b38adc4d4892c46dde32b12e47</td><td>AZ_DIET_DR_PEPPER_CF</td></tr><tr><td>47ab56f98cba40dd8ca5a3812548810a</td><td>AZ_DIET_DR_PEPPER_CHERRY</td></tr><tr><td>51f53bc929484bdc83864e2e95b23cb1</td><td>AZ_DIET_DR_PEPPER_CHERRY_VANILLA</td></tr><tr><td>2c999e924ab64a7cb7367b4acd66c455</td><td>AZ_DIET_DR_PEPPER_CREAM_SODA</td></tr><tr><td>4c15a413d46e47efbf3255b909b8fffd</td><td>AZ_DR_PEPPER</td></tr><tr><td>e7f2a41949514a5d85976f78eb96fe34</td><td>AZ_DR_PEPPER_CF</td></tr><tr><td>b06c9cfa2f6b462883bfe606eef28e75</td><td>AZ_DR_PEPPER_CHERRY</td></tr><tr><td>61af156a9d8a4f348a46541865cdf892</td><td>AZ_DR_PEPPER_CHERRY_ZERO_SUGAR</td></tr><tr><td>2732b840c67847f3b50635c5eaed22dc</td><td>AZ_DR_PEPPER_CREAM_SODA</td></tr><tr><td>d992a17807c848e2b6ceb4d9efdb3826</td><td>AZ_DR_PEPPER_CREAM_SODA_ZERO_SUGAR</td></tr><tr><td>f35b8e2f6d9640a69870059547c37eea</td><td>AZ_DR_PEPPER_DARK_BERRY</td></tr><tr><td>59da376aeec545ff9891339a5d8063fa</td><td>AZ_DR_PEPPER_ZERO_SUGAR</td></tr><tr><td>51fc27b6ce434b5da1d2455cfb41ff9a</td><td>AZ_MARSHMELLO'S_LIMITED_EDITION_COCA-COLA</td></tr><tr><td>3a0c378f19b04c8692f6fbe11918365f</td><td>AZ_MEXICAN_COKE</td></tr><tr><td>0d912cc3d01445d88201263a0e298ea8</td><td>AZ_ORANGE_VANILLA_COKE</td></tr><tr><td>8216ed0258ae4d408c186a15fa38abc3</td><td>AZ_REMAINING_BRAND</td></tr><tr><td>dd2b74b9f0d4405b8e903fa8072002f1</td><td>AZ_VANILLA_COKE</td></tr><tr><td>fbabca4a6df640f0a4b5372cfc1a22bc</td><td>CA_CHERRY_COKE</td></tr><tr><td>d700d8ce8b4045398dfe55abd77c480d</td><td>CA_CINNAMON_COKE</td></tr><tr><td>b9c18aa10375429baf58e1f0b41516d4</td><td>CA_COCA-COLA_DREAMWORLD</td></tr><tr><td>0739dfeb52734e91b75d6fc8cefbd003</td><td>CA_COKE</td></tr><tr><td>8ba8d686f5dc4b65878afb6821792314</td><td>CA_COKE_CF</td></tr><tr><td>bcb8d8d6fb1d4c2184218312c9d1cc7a</td><td>CA_COKE_CHERRY_VANILLA</td></tr><tr><td>673324e643cb42ed8455c4faff58ba20</td><td>CA_COKE_STARLIGHT</td></tr><tr><td>95574d256f16489a86bdcaf4d2d975fa</td><td>CA_DIET_DR_PEPPER</td></tr><tr><td>d94d592eb3724dcb9d65962e7859449b</td><td>CA_DIET_DR_PEPPER_CREAM_SODA</td></tr><tr><td>7101decc018f4b9eaaded78bd731ea97</td><td>CA_DR_PEPPER</td></tr><tr><td>f4e7a098c9954125912c272c9207b6dc</td><td>CA_DR_PEPPER_CHERRY</td></tr><tr><td>4b77f179e47740a29b0dcc99a30303cf</td><td>CA_DR_PEPPER_CHERRY_ZERO_SUGAR</td></tr><tr><td>ba0d1d3b3d864b43bd771fae94389ea1</td><td>CA_DR_PEPPER_CREAM_SODA</td></tr><tr><td>0cb5febe0a4e4ba98a13885d69f98110</td><td>CA_DR_PEPPER_CREAM_SODA_ZERO_SUGAR</td></tr><tr><td>44e1a0bd5be44dc4b7a31cf12747b7a4</td><td>CA_DR_PEPPER_ZERO_SUGAR</td></tr><tr><td>6aa7ca0f5570476fb1d3ffcaf6788334</td><td>CA_MEXICAN_COKE</td></tr><tr><td>312c0e1cfc3e42a5a96974ad8ff58904</td><td>CA_ORANGE_VANILLA_COKE</td></tr><tr><td>d84dd1e962294f0a84ee8aeab0e711ef</td><td>CA_VANILLA_COKE</td></tr><tr><td>fe253a001183453ca31582e63c39c060</td><td>CO_CHERRY_COKE</td></tr><tr><td>18ee5d6f570a4a0d8ff3deace7def44f</td><td>CO_CINNAMON_COKE</td></tr><tr><td>87aa52d80fb144668d37c46934c69067</td><td>CO_COCA-COLA_DREAMWORLD</td></tr><tr><td>fbe7d37b809a40b7b26458bbd05ff60a</td><t ...

# %%
runs_df[runs_df['run_name'] == 'AZ_CHERRY_COKE']['run_name'][0]
# Out:
# Out[64]: 'AZ_CHERRY_COKE'

# %%
pd.DataFrame(testss)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>weekofyear</th>
#       <th>month</th>
#       <th>quarter</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2021</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
testss = {'weekofyear': [3], 'month': [1], 'quarter':[1], 'year':[2021]}

#logged_model = 'runs:/e8444b254d1c4e22a475cf130203110a/SparkML-linear-regression'
logged_model = 'runs:/b1ddd20d82f14ac5a850176d5d0908ce/SparkML-linear-regression'


# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
loaded_model.predict(pd.DataFrame(testss))
# Out:
# Out[2]: [1.0633873032303427]

# %%
runs_df.drop_duplicates()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>run_id</th>
#       <th>tags.mlflow.runName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4435f593e60c4dc8afec8c6996ec97fe</td>
#       <td>AZ_CHERRY_COKE</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2e31412305ca41f280a981bc4fb9b178</td>
#       <td>AZ_CINNAMON_COKE</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5839cc0e725a49e08210e7e0f59b8110</td>
#       <td>AZ_COCA-COLA_DREAMWORLD</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>23bcb4eed9c24bca8566e04afbe63c4a</td>
#       <td>AZ_COKE</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7cebcd6f493c4273be56c78ec37a264b</td>
#       <td>AZ_COKE_CF</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>237</th>
#       <td>1a0466e0b4df4f6a98c4e00bd66577c4</td>
#       <td>WY_DR_PEPPER_ZERO_SUGAR</td>
#     </tr>
#     <tr>
#       <th>238</th>
#       <td>3eea4f56c6a14bb4a5587f2a20143f51</td>
#       <td>WY_MEXICAN_COKE</td>
#     </tr>
#     <tr>
#       <th>239</th>
#       <td>9e39df539a264219ab775c5e422bb3a3</td>
#       <td>WY_ORANGE_VANILLA_COKE</td>
#     </tr>
#     <tr>
#       <th>240</th>
#       <td>2d66db2be2184dafbd9f9045232cfe54</td>
#       <td>WY_REMAINING_BRAND</td>
#     </tr>
#     <tr>
#       <th>241</th>
#       <td>fc6b460868a9495cbde20d910736fbe6</td>
#       <td>WY_VANILLA_COKE</td>
#     </tr>
#   </tbody>
# </table>
# <p>242 rows × 2 columns</p>
# </div>

# %%
df[]
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>run_id</th><th>tags.mlflow.runName</th></tr></thead><tbody><tr><td>4435f593e60c4dc8afec8c6996ec97fe</td><td>AZ_CHERRY_COKE</td></tr><tr><td>2e31412305ca41f280a981bc4fb9b178</td><td>AZ_CINNAMON_COKE</td></tr><tr><td>5839cc0e725a49e08210e7e0f59b8110</td><td>AZ_COCA-COLA_DREAMWORLD</td></tr><tr><td>23bcb4eed9c24bca8566e04afbe63c4a</td><td>AZ_COKE</td></tr><tr><td>7cebcd6f493c4273be56c78ec37a264b</td><td>AZ_COKE_CF</td></tr><tr><td>d37fa577d28a4309849ca2e269755534</td><td>AZ_COKE_CHERRY_VANILLA</td></tr><tr><td>fba7fa3ceb634959bc39cbb64348bb50</td><td>AZ_COKE_STARLIGHT</td></tr><tr><td>6856e99931ee4fa19c89b4263354bd7a</td><td>AZ_COKE_W/LIME</td></tr><tr><td>4cf082c7ffc74ce69637864a4db63a1a</td><td>AZ_DIET_DR_PEPPER</td></tr><tr><td>f1a692a181e24ef7b776e2b579c74ee5</td><td>AZ_DIET_DR_PEPPER_10</td></tr><tr><td>1262f8b38adc4d4892c46dde32b12e47</td><td>AZ_DIET_DR_PEPPER_CF</td></tr><tr><td>47ab56f98cba40dd8ca5a3812548810a</td><td>AZ_DIET_DR_PEPPER_CHERRY</td></tr><tr><td>51f53bc929484bdc83864e2e95b23cb1</td><td>AZ_DIET_DR_PEPPER_CHERRY_VANILLA</td></tr><tr><td>2c999e924ab64a7cb7367b4acd66c455</td><td>AZ_DIET_DR_PEPPER_CREAM_SODA</td></tr><tr><td>4c15a413d46e47efbf3255b909b8fffd</td><td>AZ_DR_PEPPER</td></tr><tr><td>e7f2a41949514a5d85976f78eb96fe34</td><td>AZ_DR_PEPPER_CF</td></tr><tr><td>b06c9cfa2f6b462883bfe606eef28e75</td><td>AZ_DR_PEPPER_CHERRY</td></tr><tr><td>61af156a9d8a4f348a46541865cdf892</td><td>AZ_DR_PEPPER_CHERRY_ZERO_SUGAR</td></tr><tr><td>2732b840c67847f3b50635c5eaed22dc</td><td>AZ_DR_PEPPER_CREAM_SODA</td></tr><tr><td>d992a17807c848e2b6ceb4d9efdb3826</td><td>AZ_DR_PEPPER_CREAM_SODA_ZERO_SUGAR</td></tr><tr><td>f35b8e2f6d9640a69870059547c37eea</td><td>AZ_DR_PEPPER_DARK_BERRY</td></tr><tr><td>59da376aeec545ff9891339a5d8063fa</td><td>AZ_DR_PEPPER_ZERO_SUGAR</td></tr><tr><td>51fc27b6ce434b5da1d2455cfb41ff9a</td><td>AZ_MARSHMELLO'S_LIMITED_EDITION_COCA-COLA</td></tr><tr><td>3a0c378f19b04c8692f6fbe11918365f</td><td>AZ_MEXICAN_COKE</td></tr><tr><td>0d912cc3d01445d88201263a0e298ea8</td><td>AZ_ORANGE_VANILLA_COKE</td></tr><tr><td>8216ed0258ae4d408c186a15fa38abc3</td><td>AZ_REMAINING_BRAND</td></tr><tr><td>dd2b74b9f0d4405b8e903fa8072002f1</td><td>AZ_VANILLA_COKE</td></tr><tr><td>fbabca4a6df640f0a4b5372cfc1a22bc</td><td>CA_CHERRY_COKE</td></tr><tr><td>d700d8ce8b4045398dfe55abd77c480d</td><td>CA_CINNAMON_COKE</td></tr><tr><td>b9c18aa10375429baf58e1f0b41516d4</td><td>CA_COCA-COLA_DREAMWORLD</td></tr><tr><td>0739dfeb52734e91b75d6fc8cefbd003</td><td>CA_COKE</td></tr><tr><td>8ba8d686f5dc4b65878afb6821792314</td><td>CA_COKE_CF</td></tr><tr><td>bcb8d8d6fb1d4c2184218312c9d1cc7a</td><td>CA_COKE_CHERRY_VANILLA</td></tr><tr><td>673324e643cb42ed8455c4faff58ba20</td><td>CA_COKE_STARLIGHT</td></tr><tr><td>95574d256f16489a86bdcaf4d2d975fa</td><td>CA_DIET_DR_PEPPER</td></tr><tr><td>d94d592eb3724dcb9d65962e7859449b</td><td>CA_DIET_DR_PEPPER_CREAM_SODA</td></tr><tr><td>7101decc018f4b9eaaded78bd731ea97</td><td>CA_DR_PEPPER</td></tr><tr><td>f4e7a098c9954125912c272c9207b6dc</td><td>CA_DR_PEPPER_CHERRY</td></tr><tr><td>4b77f179e47740a29b0dcc99a30303cf</td><td>CA_DR_PEPPER_CHERRY_ZERO_SUGAR</td></tr><tr><td>ba0d1d3b3d864b43bd771fae94389ea1</td><td>CA_DR_PEPPER_CREAM_SODA</td></tr><tr><td>0cb5febe0a4e4ba98a13885d69f98110</td><td>CA_DR_PEPPER_CREAM_SODA_ZERO_SUGAR</td></tr><tr><td>44e1a0bd5be44dc4b7a31cf12747b7a4</td><td>CA_DR_PEPPER_ZERO_SUGAR</td></tr><tr><td>6aa7ca0f5570476fb1d3ffcaf6788334</td><td>CA_MEXICAN_COKE</td></tr><tr><td>312c0e1cfc3e42a5a96974ad8ff58904</td><td>CA_ORANGE_VANILLA_COKE</td></tr><tr><td>d84dd1e962294f0a84ee8aeab0e711ef</td><td>CA_VANILLA_COKE</td></tr><tr><td>fe253a001183453ca31582e63c39c060</td><td>CO_CHERRY_COKE</td></tr><tr><td>18ee5d6f570a4a0d8ff3deace7def44f</td><td>CO_CINNAMON_COKE</td></tr><tr><td>87aa52d80fb144668d37c46934c69067</td><td>CO_COCA-COLA_DREAMWORLD</td></tr><tr><td>fbe7d37b809a40b7b26458bbd05f ...

# %%
experiment_id = 142448669977004
df = mlflow.search_runs([experiment_id], order_by=["metrics.rmse DESC"])
df['tags.mlflow.runName'].values
# Out:
# Out[90]: array(['NM_COKE', 'AZ_COKE', 'NM_DIET_DR_PEPPER_CREAM_SODA',
#        'CA_DR_PEPPER_ZERO_SUGAR', 'OR_COKE', 'ID_COKE', 'NE_COKE',
#        'CA_DR_PEPPER_CREAM_SODA', 'WY_COKE',
#        'CA_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'NM_DR_PEPPER', 'WA_COKE',
#        'NE_DR_PEPPER', 'CA_COKE', 'WY_DR_PEPPER', 'CO_COKE',
#        'NM_DIET_DR_PEPPER_10', 'NM_DR_PEPPER_DARK_BERRY', 'CA_DR_PEPPER',
#        'ID_DIET_DR_PEPPER_CREAM_SODA', 'CA_DIET_DR_PEPPER_CREAM_SODA',
#        'WY_DIET_DR_PEPPER_CREAM_SODA',
#        'ID_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'OR_DIET_DR_PEPPER_CF',
#        'WY_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'AZ_DR_PEPPER',
#        'NM_DR_PEPPER_CREAM_SODA', 'CO_DIET_DR_PEPPER_CREAM_SODA',
#        'CO_DIET_DR_PEPPER_CHERRY', 'NM_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'OR_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'NM_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WA_DR_PEPPER_DARK_BERRY',
#        'WA_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'NE_DIET_DR_PEPPER_CF',
#        'WA_DIET_DR_PEPPER_CREAM_SODA', 'ID_DR_PEPPER_CREAM_SODA',
#        'NV_DIET_DR_PEPPER_CREAM_SODA', 'OR_DIET_DR_PEPPER_CREAM_SODA',
#        'AZ_DIET_DR_PEPPER_CREAM_SODA', 'CA_DR_PEPPER_CHERRY',
#        'OR_DR_PEPPER_CHERRY_ZERO_SUGAR', 'OR_DIET_DR_PEPPER_CHERRY',
#        'NM_DIET_DR_PEPPER', 'NM_VANILLA_COKE', 'CO_DR_PEPPER',
#        'CA_VANILLA_COKE', 'OR_DR_PEPPER', 'OR_DIET_DR_PEPPER',
#        'NM_DIET_DR_PEPPER_CF', 'ID_DR_PEPPER', 'ID_DIET_DR_PEPPER_10',
#        'NM_COKE_CHERRY_VANILLA', 'ID_DIET_DR_PEPPER_CHERRY_VANILLA',
#        'CO_DIET_DR_PEPPER_CF', 'WA_DIET_DR_PEPPER_CF', 'NV_MEXICAN_COKE',
#        'NE_DIET_DR_PEPPER_CREAM_SODA', 'NM_DR_PEPPER_CHERRY',
#        'WY_DR_PEPPER_CHERRY', 'WA_DIET_DR_PEPPER_10', 'WY_VANILLA_COKE',
#        'WY_DIET_DR_PEPPER_CF', 'NM_COKE_STARLIGHT',
#        'WA_DIET_DR_PEPPER_CHERRY', 'CA_DIET_DR_PEPPER', 'WA_VANILLA_COKE',
#        'OR_DIET_DR_PEPPER_10', 'NV_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'NM_DR_PEPPER_ZERO_SUGAR', 'WA_DR_PEPPER', 'NE_DIET_DR_PEPPER',
#        'NE_DR_PEPPER_CREAM_SODA', 'CO_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'OR_DR_PEPPER_CHERRY', 'WA_DIET_DR_PEPPER', 'NE_COKE_CF',
#        'AZ_DIET_DR_PEPPER_CHERRY', 'NV_COKE_CF', 'WY_DIET_DR_PEPPER',
#        'NV_COKE', 'WA_DR_PEPPER_CHERRY', 'WY_DR_PEPPER_CHERRY_ZERO_SUGAR',
#        'WY_DR_PEPPER_CREAM_SODA', 'NE_DR_PEPPER_DARK_BERRY', 'NM_COKE_CF',
#        'ID_DIET_DR_PEPPER_CF', 'CA_COKE_CHERRY_VANILLA', 'WY_COKE_CF',
#        'WY_CHERRY_COKE', 'AZ_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'WA_DR_PEPPER_CREAM_SODA', 'CA_COKE_STARLIGHT',
#        'AZ_DIET_DR_PEPPER_CF', 'OR_DR_PEPPER_CREAM_SODA',
#        'OR_DIET_DR_PEPPER_CHERRY_VANILLA', 'OR_VANILLA_COKE',
#        'WY_DR_PEPPER_DARK_BERRY', 'NE_DR_PEPPER_CHERRY',
#        'NM_DIET_DR_PEPPER_CHERRY', 'AZ_COKE_CF', 'NE_CHERRY_COKE',
#        'OR_DR_PEPPER_DARK_BERRY', 'NE_DIET_DR_PEPPER_CHERRY',
#        'ID_DIET_DR_PEPPER_CHERRY', 'ID_DR_PEPPER_DARK_BERRY',
#        'NE_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'WA_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WA_COKE_CF',
#        'NV_DR_PEPPER_DARK_BERRY', 'ID_DIET_DR_PEPPER',
#        'NM_ORANGE_VANILLA_COKE', 'CO_COKE_CF', 'OR_COKE_CF', 'ID_COKE_CF',
#        'WY_COKE_CHERRY_VANILLA', 'NE_COKE_CHERRY_VANILLA',
#        'ID_DR_PEPPER_ZERO_SUGAR', 'NM_CHERRY_COKE',
#        'ID_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WA_COCA-COLA_DREAMWORLD',
#        'AZ_DIET_DR_PEPPER', 'CO_DR_PEPPER_CHERRY', 'AZ_VANILLA_COKE',
#        'NV_DIET_DR_PEPPER_CHERRY', 'CO_DIET_DR_PEPPER', 'CO_VANILLA_COKE',
#        'CO_DR_PEPPER_DARK_BERRY', 'WY_DR_PEPPER_ZERO_SUGAR',
#        'CA_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WY_DIET_DR_PEPPER_CHERRY',
#        'CA_CHERRY_COKE', 'CO_DR_PEPPER_CHERRY_ZERO_SUGAR',
#        'ID_VANILLA_COKE', 'NV_DR_PEPPER_CHERRY', 'CA_COKE_CF',
#        'AZ_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WY_ORANGE_VANILLA_COKE',
#        'NV_DR_PEPPER_CHERRY_ZERO_SUGAR', 'NE_DR_PEPPER_CHERRY_ZERO_SUGAR',
#        'NE_ORANGE_VANILLA_COKE', 'AZ_DIET_DR_PEPPER_10', 'WA_CHERRY_COKE',
#        'ID_COKE_CHERRY_VANILLA', 'CA_ORANGE_VANILLA_COKE',
#        'ID_CHERRY_COKE', 'CO_ORANGE_VANILLA_COKE', 'NV_DR_PEPPER',
#        'AZ_DR_PEPPER_CREAM_SODA', 'WA_COKE_CHERRY_VANILLA',
#        'NE_DR_PEPPER_ZERO_SUGAR', 'WA_COKE_STARLIGHT',
#        'AZ_DR_PEPPER_ZERO_SUGAR', 'OR_COCA-COLA_DREAMWORLD',
#        'NM_DIET_DR_PEPPER_CHERRY_VANILLA', 'ID_ORANGE_VANILLA_COKE',
#        'NV_DR_PEPPER_ZERO_SUGAR', 'AZ_CHERRY_COKE', 'AZ_DR_PEPPER_CHERRY',
#        'CO_DR_PEPPER_CREAM_SODA', 'OR_COKE_CHERRY_VANILLA',
#        'NE_COKE_STARLIGHT', 'OR_CHERRY_COKE', 'CO_CHERRY_COKE',
#        'OR_DR_PEPPER_ZERO_SUGAR', 'AZ_DIET_DR_PEPPER_CHERRY_VANILLA',
#        'WA_ORANGE_VANILLA_COKE', 'OR_COKE_STARLIGHT',
#        'AZ_COKE_CHERRY_VANILLA', 'NV_DR_PEPPER_CREAM_SODA',
#        'NV_VANILLA_COKE', 'ID_DR_PEPPER_CHERRY', 'CO_COKE_CHERRY_VANILLA',
#        'NE_VANILLA_COKE', 'NM_MEXICAN_COKE', 'OR_ORANGE_VANILLA_COKE',
#        'CA_CINNAMON_COKE', 'CO_COKE_STARLIGHT', 'NV_DIET_DR_PEPPER',
#        'WA_DR_PEPPER_ZERO_SUGAR', 'CO_DR_PEPPER_ZERO_SUGAR',
#        'AZ_MEXICAN_COKE', 'NE_MEXICAN_COKE', 'ID_COKE_STARLIGHT',
#        'NM_CINNAMON_COKE', 'NV_COKE_CHERRY_VANILLA', 'CA_MEXICAN_COKE',
#        'ID_CINNAMON_COKE', 'NV_COCA-COLA_DREAMWORLD',
#        'WY_COCA-COLA_DREAMWORLD', 'NV_CHERRY_COKE',
#        'CO_COCA-COLA_DREAMWORLD', 'ID_COCA-COLA_DREAMWORLD',
#        'NE_COCA-COLA_DREAMWORLD', 'NM_COCA-COLA_DREAMWORLD',
#        'NV_COKE_STARLIGHT', 'AZ_ORANGE_VANILLA_COKE', 'AZ_COKE_STARLIGHT',
#        'WY_CINNAMON_COKE', 'WY_COKE_STARLIGHT', 'WA_MEXICAN_COKE',
#        'AZ_DR_PEPPER_DARK_BERRY', 'OR_CINNAMON_COKE', 'WA_CINNAMON_COKE',
#        'WY_DR_PEPPER_CF', 'CO_CINNAMON_COKE', 'WY_MEXICAN_COKE',
#        'NV_DIET_DR_PEPPER_CF', 'OR_MEXICAN_COKE',
#        'NV_ORANGE_VANILLA_COKE', 'CO_MEXICAN_COKE', 'NV_CINNAMON_COKE',
#        'ID_MEXICAN_COKE', 'AZ_CINNAMON_COKE', 'AZ_COCA-COLA_DREAMWORLD',
#        'CA_COCA-COLA_DREAMWORLD', 'NE_CINNAMON_COKE',
#        "AZ_MARSHMELLO'S_LIMITED_EDITION_COCA-COLA", 'OR_DR_PEPPER_CF',
#        'CO_DR_PEPPER_CHERRY_VANILLA',
#        "WA_MARSHMELLO'S_LIMITED_EDITION_COCA-COLA", 'NM_DR_PEPPER_CF',
#        'WA_REMAINING_BRAND', 'OR_COKE_W/LIME', 'OR_REMAINING_BRAND',
#        'AZ_REMAINING_BRAND', 'AZ_COKE_W/LIME', 'WA_COKE_W/LIME',
#        'AZ_DR_PEPPER_CF', 'WY_REMAINING_BRAND', 'WY_COKE_W/LIME',
#        'WA_HERITAGE_DR_PEPPER', 'NV_REMAINING_BRAND',
#        'NV_DIET_DR_PEPPER_CHERRY_VANILLA', 'NV_DIET_DR_PEPPER_10',
#        'NM_REMAINING_BRAND', 'NM_COKE_W/LIME', 'ID_REMAINING_BRAND',
#        'ID_COKE_W/LIME', 'CO_REMAINING_BRAND', 'CO_DR_PEPPER_CF',
#        'CO_COKE_W/LIME'], dtype=object)

# %%
# Out:
# Out[80]: ['142448669977004']

# %%
[x for x in if dict(experiments[0]).get('name').find('keyBrand') > 0]
# Out:
# Out[75]: 50

# %%
msk = 'model_state_keyBrand'
mlflow.get_experiment_by_name(msk).name
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/databricks/python/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<command-4394589272978372>", line 2, in <module>
#     mlflow.get_experiment_by_name(msk).name
# AttributeError: 'NoneType' object has no attribute 'name'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/databricks/python/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1997, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/databricks/python/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/databricks/python/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/databricks/python/lib/python3.9/site-packages/IPython/core/ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/databricks/python/lib/python3.9/site-packages/IPython/core/ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/databricks/python/lib/python3.9/site-packages/IPython/core/ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/databricks/python/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/databricks/python/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/databricks/python/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/databricks/python/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/databricks/python/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/databricks/python/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/databricks/python/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
RN = 'WY_VANILLA_COKE'
mlflow.search_runs()
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# File <command-4394589272978406>:2
#       1 RN = 'WY_VANILLA_COKE'
# ----> 2 mlflow.search_runs(RN)
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/tracking/fluent.py:1448, in search_runs(experiment_ids, filter_string, run_view_type, max_results, order_by, output_format, search_all_experiments, experiment_names)
#    1438 def pagination_wrapper_func(number_to_get, next_page_token):
#    1439     return MlflowClient().search_runs(
#    1440         experiment_ids,
#    1441         filter_string,
#    (...)
#    1445         next_page_token,
#    1446     )
# -> 1448 runs = get_results_from_paginated_fn(
#    1449     pagination_wrapper_func,
#    1450     NUM_RUNS_PER_PAGE_PANDAS,
#    1451     max_results,
#    1452 )
#    1454 if output_format == "list":
#    1455     return runs  # List[mlflow.entities.run.Run]
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/utils/__init__.py:249, in get_results_from_paginated_fn(paginated_fn, max_results_per_page, max_results)
#     247     page_results = paginated_fn(num_to_get, next_page_token)
#     248 else:
# --> 249     page_results = paginated_fn(max_results_per_page, next_page_token)
#     250 all_results.extend(page_results)
#     251 if hasattr(page_results, "token") and page_results.token:
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/tracking/fluent.py:1439, in search_runs.<locals>.pagination_wrapper_func(number_to_get, next_page_token)
#    1438 def pagination_wrapper_func(number_to_get, next_page_token):
# -> 1439     return MlflowClient().search_runs(
#    1440         experiment_ids,
#    1441         filter_string,
#    1442         run_view_type,
#    1443         number_to_get,
#    1444         order_by,
#    1445         next_page_token,
#    1446     )
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/tracking/client.py:1665, in MlflowClient.search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#    1577 def search_runs(
#    1578     self,
#    1579     experiment_ids: List[str],
#    (...)
#    1584     page_token: Optional[str] = None,
#    1585 ) -> PagedList[Run]:
#    1586     """
#    1587     Search for Runs that fit the specified criteria.
#    1588
#    (...)
#    1663         tags: {'s.release': '1.1.0-RC'}
#    1664     """
# -> 1665     return self._tracking_client.search_runs(
#    1666         experiment_ids, filter_string, run_view_type, max_results, order_by, page_token
#    1667     )
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:511, in TrackingServiceClient.search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     509 if isinstance(experiment_ids, int) or is_string_type(experiment_ids):
#     510     experiment_ids = [experiment_ids]
# --> 511 return self.store.search_runs(
#     512     experiment_ids=experiment_ids,
#     513     filter_string=filter_string,
#     514     run_view_type=run_view_type,
#     515     max_results=max_results,
#     516     order_by=order_by,
#     517     page_token=page_token,
#     518 )
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/store/tracking/abstract_store.py:285, in AbstractStore.search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     258 def search_runs(
#     259     self,
#     260     experiment_ids,
#    (...)
#     265     page_token=None,
#     266 ):
#     267     """
#     268     Return runs that match the given list of search expressions within the experiments.
#     269
#    (...)
#     283         meaningful in such cases.
#     284     """
# --> 285     runs, token = self._search_runs(
#     286         experiment_ids, filter_string, run_view_type, max_results, order_by, page_token
#     287     )
#     288     return PagedList(runs, token)
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py:271, in RestStore._search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     262 sr = SearchRuns(
#     263     experiment_ids=experiment_ids,
#     264     filter=filter_string,
#    (...)
#     268     page_token=page_token,
#     269 )
#     270 req_body = message_to_json(sr)
# --> 271 response_proto = self._call_endpoint(SearchRuns, req_body)
#     272 runs = [Run.from_proto(proto_run) for proto_run in response_proto.runs]
#     273 # If next_page_token is not set, we will see it as "". We need to convert this to None.
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py:56, in RestStore._call_endpoint(self, api, json_body)
#      54 endpoint, method = _METHOD_TO_INFO[api]
#      55 response_proto = api.Response()
# ---> 56 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/utils/rest_utils.py:280, in call_endpoint(host_creds, endpoint, method, json_body, response_proto)
#     276 else:
#     277     response = http_request(
#     278         host_creds=host_creds, endpoint=endpoint, method=method, json=json_body
#     279     )
# --> 280 response = verify_rest_response(response, endpoint)
#     281 js_dict = json.loads(response.text)
#     282 parse_dict(js_dict=js_dict, message=response_proto)
#
# File /databricks/python/lib/python3.9/site-packages/mlflow/utils/rest_utils.py:206, in verify_rest_response(response, endpoint)
#     204 if response.status_code != 200:
#     205     if _can_parse_as_json_object(response.text):
# --> 206         raise RestException(json.loads(response.text))
#     207     else:
#     208         base_msg = "API request to endpoint %s failed with error code %s != 200" % (
#     209             endpoint,
#     210             response.status_code,
#     211         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: One or more of the specified experiments does not exist.

# %%
experiment_id = 142448669977004
df = mlflow.search_runs([experiment_id], order_by=["metrics.rmse DESC"])
df['tags.mlflow.runName'].values
# Out:
# Out[34]: array(['NM_COKE', 'AZ_COKE', 'NM_DIET_DR_PEPPER_CREAM_SODA',
#        'CA_DR_PEPPER_ZERO_SUGAR', 'OR_COKE', 'ID_COKE', 'NE_COKE',
#        'CA_DR_PEPPER_CREAM_SODA', 'WY_COKE',
#        'CA_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'NM_DR_PEPPER', 'WA_COKE',
#        'NE_DR_PEPPER', 'CA_COKE', 'WY_DR_PEPPER', 'CO_COKE',
#        'NM_DIET_DR_PEPPER_10', 'NM_DR_PEPPER_DARK_BERRY', 'CA_DR_PEPPER',
#        'ID_DIET_DR_PEPPER_CREAM_SODA', 'CA_DIET_DR_PEPPER_CREAM_SODA',
#        'WY_DIET_DR_PEPPER_CREAM_SODA',
#        'ID_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'OR_DIET_DR_PEPPER_CF',
#        'WY_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'AZ_DR_PEPPER',
#        'NM_DR_PEPPER_CREAM_SODA', 'CO_DIET_DR_PEPPER_CREAM_SODA',
#        'CO_DIET_DR_PEPPER_CHERRY', 'NM_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'OR_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'NM_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WA_DR_PEPPER_DARK_BERRY',
#        'WA_DR_PEPPER_CREAM_SODA_ZERO_SUGAR', 'NE_DIET_DR_PEPPER_CF',
#        'WA_DIET_DR_PEPPER_CREAM_SODA', 'ID_DR_PEPPER_CREAM_SODA',
#        'NV_DIET_DR_PEPPER_CREAM_SODA', 'OR_DIET_DR_PEPPER_CREAM_SODA',
#        'AZ_DIET_DR_PEPPER_CREAM_SODA', 'CA_DR_PEPPER_CHERRY',
#        'OR_DR_PEPPER_CHERRY_ZERO_SUGAR', 'OR_DIET_DR_PEPPER_CHERRY',
#        'NM_DIET_DR_PEPPER', 'NM_VANILLA_COKE', 'CO_DR_PEPPER',
#        'CA_VANILLA_COKE', 'OR_DR_PEPPER', 'OR_DIET_DR_PEPPER',
#        'NM_DIET_DR_PEPPER_CF', 'ID_DR_PEPPER', 'ID_DIET_DR_PEPPER_10',
#        'NM_COKE_CHERRY_VANILLA', 'ID_DIET_DR_PEPPER_CHERRY_VANILLA',
#        'CO_DIET_DR_PEPPER_CF', 'WA_DIET_DR_PEPPER_CF', 'NV_MEXICAN_COKE',
#        'NE_DIET_DR_PEPPER_CREAM_SODA', 'NM_DR_PEPPER_CHERRY',
#        'WY_DR_PEPPER_CHERRY', 'WA_DIET_DR_PEPPER_10', 'WY_VANILLA_COKE',
#        'WY_DIET_DR_PEPPER_CF', 'NM_COKE_STARLIGHT',
#        'WA_DIET_DR_PEPPER_CHERRY', 'CA_DIET_DR_PEPPER', 'WA_VANILLA_COKE',
#        'OR_DIET_DR_PEPPER_10', 'NV_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'NM_DR_PEPPER_ZERO_SUGAR', 'WA_DR_PEPPER', 'NE_DIET_DR_PEPPER',
#        'NE_DR_PEPPER_CREAM_SODA', 'CO_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'OR_DR_PEPPER_CHERRY', 'WA_DIET_DR_PEPPER', 'NE_COKE_CF',
#        'AZ_DIET_DR_PEPPER_CHERRY', 'NV_COKE_CF', 'WY_DIET_DR_PEPPER',
#        'NV_COKE', 'WA_DR_PEPPER_CHERRY', 'WY_DR_PEPPER_CHERRY_ZERO_SUGAR',
#        'WY_DR_PEPPER_CREAM_SODA', 'NE_DR_PEPPER_DARK_BERRY', 'NM_COKE_CF',
#        'ID_DIET_DR_PEPPER_CF', 'CA_COKE_CHERRY_VANILLA', 'WY_COKE_CF',
#        'WY_CHERRY_COKE', 'AZ_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'WA_DR_PEPPER_CREAM_SODA', 'CA_COKE_STARLIGHT',
#        'AZ_DIET_DR_PEPPER_CF', 'OR_DR_PEPPER_CREAM_SODA',
#        'OR_DIET_DR_PEPPER_CHERRY_VANILLA', 'OR_VANILLA_COKE',
#        'WY_DR_PEPPER_DARK_BERRY', 'NE_DR_PEPPER_CHERRY',
#        'NM_DIET_DR_PEPPER_CHERRY', 'AZ_COKE_CF', 'NE_CHERRY_COKE',
#        'OR_DR_PEPPER_DARK_BERRY', 'NE_DIET_DR_PEPPER_CHERRY',
#        'ID_DIET_DR_PEPPER_CHERRY', 'ID_DR_PEPPER_DARK_BERRY',
#        'NE_DR_PEPPER_CREAM_SODA_ZERO_SUGAR',
#        'WA_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WA_COKE_CF',
#        'NV_DR_PEPPER_DARK_BERRY', 'ID_DIET_DR_PEPPER',
#        'NM_ORANGE_VANILLA_COKE', 'CO_COKE_CF', 'OR_COKE_CF', 'ID_COKE_CF',
#        'WY_COKE_CHERRY_VANILLA', 'NE_COKE_CHERRY_VANILLA',
#        'ID_DR_PEPPER_ZERO_SUGAR', 'NM_CHERRY_COKE',
#        'ID_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WA_COCA-COLA_DREAMWORLD',
#        'AZ_DIET_DR_PEPPER', 'CO_DR_PEPPER_CHERRY', 'AZ_VANILLA_COKE',
#        'NV_DIET_DR_PEPPER_CHERRY', 'CO_DIET_DR_PEPPER', 'CO_VANILLA_COKE',
#        'CO_DR_PEPPER_DARK_BERRY', 'WY_DR_PEPPER_ZERO_SUGAR',
#        'CA_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WY_DIET_DR_PEPPER_CHERRY',
#        'CA_CHERRY_COKE', 'CO_DR_PEPPER_CHERRY_ZERO_SUGAR',
#        'ID_VANILLA_COKE', 'NV_DR_PEPPER_CHERRY', 'CA_COKE_CF',
#        'AZ_DR_PEPPER_CHERRY_ZERO_SUGAR', 'WY_ORANGE_VANILLA_COKE',
#        'NV_DR_PEPPER_CHERRY_ZERO_SUGAR', 'NE_DR_PEPPER_CHERRY_ZERO_SUGAR',
#        'NE_ORANGE_VANILLA_COKE', 'AZ_DIET_DR_PEPPER_10', 'WA_CHERRY_COKE',
#        'ID_COKE_CHERRY_VANILLA', 'CA_ORANGE_VANILLA_COKE',
#        'ID_CHERRY_COKE', 'CO_ORANGE_VANILLA_COKE', 'NV_DR_PEPPER',
#        'AZ_DR_PEPPER_CREAM_SODA', 'WA_COKE_CHERRY_VANILLA',
#        'NE_DR_PEPPER_ZERO_SUGAR', 'WA_COKE_STARLIGHT',
#        'AZ_DR_PEPPER_ZERO_SUGAR', 'OR_COCA-COLA_DREAMWORLD',
#        'NM_DIET_DR_PEPPER_CHERRY_VANILLA', 'ID_ORANGE_VANILLA_COKE',
#        'NV_DR_PEPPER_ZERO_SUGAR', 'AZ_CHERRY_COKE', 'AZ_DR_PEPPER_CHERRY',
#        'CO_DR_PEPPER_CREAM_SODA', 'OR_COKE_CHERRY_VANILLA',
#        'NE_COKE_STARLIGHT', 'OR_CHERRY_COKE', 'CO_CHERRY_COKE',
#        'OR_DR_PEPPER_ZERO_SUGAR', 'AZ_DIET_DR_PEPPER_CHERRY_VANILLA',
#        'WA_ORANGE_VANILLA_COKE', 'OR_COKE_STARLIGHT',
#        'AZ_COKE_CHERRY_VANILLA', 'NV_DR_PEPPER_CREAM_SODA',
#        'NV_VANILLA_COKE', 'ID_DR_PEPPER_CHERRY', 'CO_COKE_CHERRY_VANILLA',
#        'NE_VANILLA_COKE', 'NM_MEXICAN_COKE', 'OR_ORANGE_VANILLA_COKE',
#        'CA_CINNAMON_COKE', 'CO_COKE_STARLIGHT', 'NV_DIET_DR_PEPPER',
#        'WA_DR_PEPPER_ZERO_SUGAR', 'CO_DR_PEPPER_ZERO_SUGAR',
#        'AZ_MEXICAN_COKE', 'NE_MEXICAN_COKE', 'ID_COKE_STARLIGHT',
#        'NM_CINNAMON_COKE', 'NV_COKE_CHERRY_VANILLA', 'CA_MEXICAN_COKE',
#        'ID_CINNAMON_COKE', 'NV_COCA-COLA_DREAMWORLD',
#        'WY_COCA-COLA_DREAMWORLD', 'NV_CHERRY_COKE',
#        'CO_COCA-COLA_DREAMWORLD', 'ID_COCA-COLA_DREAMWORLD',
#        'NE_COCA-COLA_DREAMWORLD', 'NM_COCA-COLA_DREAMWORLD',
#        'NV_COKE_STARLIGHT', 'AZ_ORANGE_VANILLA_COKE', 'AZ_COKE_STARLIGHT',
#        'WY_CINNAMON_COKE', 'WY_COKE_STARLIGHT', 'WA_MEXICAN_COKE',
#        'AZ_DR_PEPPER_DARK_BERRY', 'OR_CINNAMON_COKE', 'WA_CINNAMON_COKE',
#        'WY_DR_PEPPER_CF', 'CO_CINNAMON_COKE', 'WY_MEXICAN_COKE',
#        'NV_DIET_DR_PEPPER_CF', 'OR_MEXICAN_COKE',
#        'NV_ORANGE_VANILLA_COKE', 'CO_MEXICAN_COKE', 'NV_CINNAMON_COKE',
#        'ID_MEXICAN_COKE', 'AZ_CINNAMON_COKE', 'AZ_COCA-COLA_DREAMWORLD',
#        'CA_COCA-COLA_DREAMWORLD', 'NE_CINNAMON_COKE',
#        "AZ_MARSHMELLO'S_LIMITED_EDITION_COCA-COLA", 'OR_DR_PEPPER_CF',
#        'CO_DR_PEPPER_CHERRY_VANILLA',
#        "WA_MARSHMELLO'S_LIMITED_EDITION_COCA-COLA", 'NM_DR_PEPPER_CF',
#        'WA_REMAINING_BRAND', 'OR_COKE_W/LIME', 'OR_REMAINING_BRAND',
#        'AZ_REMAINING_BRAND', 'AZ_COKE_W/LIME', 'WA_COKE_W/LIME',
#        'AZ_DR_PEPPER_CF', 'WY_REMAINING_BRAND', 'WY_COKE_W/LIME',
#        'WA_HERITAGE_DR_PEPPER', 'NV_REMAINING_BRAND',
#        'NV_DIET_DR_PEPPER_CHERRY_VANILLA', 'NV_DIET_DR_PEPPER_10',
#        'NM_REMAINING_BRAND', 'NM_COKE_W/LIME', 'ID_REMAINING_BRAND',
#        'ID_COKE_W/LIME', 'CO_REMAINING_BRAND', 'CO_DR_PEPPER_CF',
#        'CO_COKE_W/LIME'], dtype=object)

# %%
run_names_list = df['tags.mlflow.runName'].values
print(len(run_names_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4394589272978350>:1
# ----> 1 run_names_list = df['tags.mlflow.runName'].values
#       2 print(len(run_names_list))
#
# NameError: name 'df' is not defined

# %%
import requests
response = requests.get("https://adb-4647227049398975.15.azuredatabricks.net/?o=4647227049398975#mlflow/experiments")

# %%
b1ddd20d82f14ac5a850176d5d0908ce
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File <command-4394589272978411>:1
# ----> 1 from databricks_api import DatabricksAPI
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# ModuleNotFoundError: No module named 'databricks_api'
